# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Analysis comparing salaries of MLS soccer players

# %% [markdown]
# ## Data Input

# %%
mls = pd.read_csv("./mls-salaries-2017.csv").dropna()
print(f"Data Shape: {mls.shape}")
print(mls.head())
# Out:
# Data Shape: (610, 6)
#   club last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL   Almiron     Miguel        M    1912500.0               2297000.00
# 1  ATL   Ambrose      Mikey        D      65625.0                 65625.00
# 2  ATL      Asad      Yamil        M     150000.0                150000.00
# 3  ATL     Bloom       Mark        D      99225.0                106573.89
# 4  ATL  Carleton     Andrew        F      65000.0                 77400.00

# %% [markdown]
# ## Filter Data by Forward, Midfielder, Defender

# %%
# mls = mls[mls['position'] !='GK']
# mls = mls[mls['position'] !='M-F']
# mls = mls[mls['position'] !='F-M']
# mls = mls[mls['position'] !='D-M']
# mls = mls[mls['position'] !='M-D']
# mls = mls[mls['position'] !='M/F']
# mls = mls[mls['position'] !='F/M']

f = mls[mls['position'] =='F']
m = mls[mls['position'] =='M']
d = mls[mls['position'] =='D']
mls = [f,m,d]
mls = pd.concat(mls)
mls
# Out:
#     club  last_name first_name position  base_salary  guaranteed_compensation
# 4    ATL   Carleton     Andrew        F      65000.0                 77400.00
# 11   ATL      Jones    Kenwyne        F     390000.0                413333.33
# 16   ATL   Martinez      Josef        F     924000.0               1041310.00
# 21   ATL   Peterson      Jacob        F     165300.0                165300.00
# 24   ATL     Rochez      Bryan        F     200000.0                279500.00
# ..   ...        ...        ...      ...          ...                      ...
# 600  VAN  Nerwinski       Jake        D      65004.0                 65004.00
# 602  VAN     Parker        Tim        D      80850.0                 99600.00
# 606  VAN     Seiler       Cole        D      54075.0                 54075.00
# 612  VAN     Waston    Kendall        D     350000.0                368125.00
# 613  VAN   Williams    Sheanon        D     175000.0                184000.00
#
# [500 rows x 6 columns]

# %% [markdown]
# ## Define x and y values

# %%
X = mls['position'].values
# player_position = mls['position'].values
# X = mls['position'] == M or D or F
y = mls['base_salary'].values

# %%
# sns.relplot(x="position", y="base_salary", data=mls)

# %% [markdown]
# ## Graph the data

# %%
sns.barplot(x="position", y="base_salary", data=mls)

# %% [markdown]
# ## Deep Thoughts by Corey

# %% [markdown]
# 1) There is a fairly linear coorelation between paying a defender the least to being paid the most as a forward, with midfielder in the middle.
# 2) There is also a lot more variation as a forward with less as a more defensive player
